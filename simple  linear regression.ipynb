# %%
import matplotlib.pyplot as plt

# %%
x =[2600,3000,3200,3600,4000]
y =[5500000,5800000,6100000,6800000,7200000]
plt.scatter(x,y,label='data',color='m')
plt.xlabel("area")
plt.ylabel("price",color='g')
plt.title("AREA-PRICE")
plt.legend()
plt.show()
